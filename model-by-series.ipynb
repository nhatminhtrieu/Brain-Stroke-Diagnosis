# %%
# Constants
BATCH_SIZE = 8
CHUNK_SIZE = 8
START_IDX = 0
MAX_IMAGES_PER_SERIES = 128
CHECKPOINT_PATH = '/kaggle/working/model_checkpoint.pth'
IMG_SIZE = (224, 224)
NUM_EPOCHS = 5
LEARNING_RATE = 5e-7
LOSS_FUNCTION = 'binary_crossentropy'
METRICS = ['accuracy']

import os
import pandas as pd
import numpy as np
import pydicom
import psutil
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
from torchvision import models
from skimage.transform import resize
from sklearn.model_selection import train_test_split
import gc
import warnings
import os
import glob
import torch
import torch.nn as nn
import torch.optim as optim
from torch.amp import autocast, GradScaler

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def read_clinical_data(file_path):
    xls = pd.ExcelFile(file_path)
    sheet_names_lower = [sheet.lower() for sheet in xls.sheet_names]
    clinical_sheet = [sheet for sheet in sheet_names_lower if 'clinical' in sheet 
                      or 'клинические' in sheet 
                      or 'сlinical' in sheet]
    if not clinical_sheet:
        raise ValueError('No clinical sheet found in the XLSX file.')
    
    original_sheet_name = xls.sheet_names[sheet_names_lower.index(clinical_sheet[0])]
    df_clinical = pd.read_excel(xls, original_sheet_name)
    return df_clinical

def read_dicom_files(study_path):
    dicom_series = {}
    for series in os.listdir(study_path):
        series_path = os.path.join(study_path, series)
        if os.path.isdir(series_path):
            series_images = []
            for file in os.listdir(series_path):
                if file.endswith('.dcm'):
                    dicom_path = os.path.join(series_path, file)
                    dicom_image = pydicom.dcmread(dicom_path, force=True)
                    if 'SamplesPerPixel' not in dicom_image:
                        dicom_image.SamplesPerPixel = 1
                    if 'PhotometricInterpretation' not in dicom_image:
                        dicom_image.PhotometricInterpretation = 'MONOCHROME2'
                    series_images.append(dicom_image)
            if series_images:
                dicom_series[series] = series_images
    return dicom_series

def preprocess_images(dicom_images):
    preprocessed_images = []
    for dicom_image in dicom_images:
        image_array = dicom_image.pixel_array
        max_value = np.max(image_array)
        image_array = image_array / max_value if max_value > 0 else np.zeros_like(image_array)
        resized_image = resize(image_array, IMG_SIZE, anti_aliasing=True)
        rgb_image = np.stack((resized_image,) * 3, axis=-1) if len(resized_image.shape) == 2 else resized_image
        preprocessed_images.append(rgb_image)
    return np.array(preprocessed_images)

def process_batch(studies_folder, dataset_path, start_idx=START_IDX, batch_size=BATCH_SIZE, max_images_per_series=MAX_IMAGES_PER_SERIES):
    all_processed_series = {}
    all_clinical_data = pd.DataFrame()
    
    target_columns = ['epidural hemorrhage', 'subarachnoid hemorrhage', 'subdural hemorrhage', 
                      'intracerebral hemorrhage', 'multiple hemorrhages', 'skull fracture']
    
    if studies_folder != '200_300_studies':
        studies_folder_path = os.path.join(dataset_path, studies_folder, studies_folder)
        print(f"Processing folder {studies_folder}")
        xlsx_files = [f for f in os.listdir(studies_folder_path) if f.endswith('.xlsx')]
        
        if len(xlsx_files) == 1:
            clinical_data_path = os.path.join(studies_folder_path, xlsx_files[0])
            clinical_data = read_clinical_data(clinical_data_path)    
            clinical_data.columns = clinical_data.columns.str.lower()
            clinical_data = clinical_data[clinical_data['comment'] != 'Study without report']

            # Check if target columns are binary and drop non-binary rows
            for column in target_columns:
                if column in clinical_data.columns:
                    clinical_data = clinical_data[clinical_data[column].isin([0, 1])]
                else:
                    print(f"Warning: Column '{column}' not found in clinical data.")

            study_uids_in_folder = [uid for uid in os.listdir(studies_folder_path) if os.path.isdir(os.path.join(studies_folder_path, uid))]
            
            for study_uid in study_uids_in_folder[start_idx:start_idx+batch_size]:
                study_path = os.path.join(studies_folder_path, study_uid)
                
                dicom_series = read_dicom_files(study_path)
                
                for series_uid, series_images in dicom_series.items():
                    processed_images = preprocess_images(series_images)
                    
                    if len(processed_images) > 0:
                        if study_uid not in all_processed_series:
                            all_processed_series[study_uid] = {}
                        all_processed_series[study_uid][series_uid] = processed_images
                        
                        study_clinical_data = clinical_data[clinical_data['study_uid'] == study_uid]
                        if not study_clinical_data.empty:
                            all_clinical_data = pd.concat([all_clinical_data, study_clinical_data], ignore_index=True)
                            print(f"Processed {len(series_images)} DICOM images for study UID: {study_uid}, series UID: {series_uid}")
                        else:
                            print(f"Warning: No clinical data found for study UID: {study_uid}")
                    else:
                        print(f"No images processed for study UID: {study_uid}, series UID: {series_uid}")

        else:
            print(f"Error: Expected exactly one XLSX file in {studies_folder_path}")

    print("Number of processed studies:", len(all_processed_series))
    print("Number of rows in clinical data:", len(all_clinical_data))

    patient_data = {}

    for study_uid, series_dict in all_processed_series.items():
        study_clinical_data = all_clinical_data[all_clinical_data['study_uid'] == study_uid]
        if not study_clinical_data.empty:
            patient_data[study_uid] = {
                'images': series_dict,
                'labels': study_clinical_data.iloc[0][target_columns].to_dict()
            }
        else:
            print(f"Warning: No clinical data for study UID: {study_uid}")

    return patient_data, all_clinical_data, start_idx + len(all_processed_series)

from torchvision.models.resnet import ResNet50_Weights

def create_or_load_model(checkpoint_path):
    model = models.resnet50(weights=ResNet50_Weights.DEFAULT)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 6)  # Change to 6 outputs for 6 labels
    
    if os.path.exists(checkpoint_path):
        print(f"Attempting to load checkpoint from {checkpoint_path}")
        try:
            checkpoint = torch.load(checkpoint_path, weights_only=True)
            model.load_state_dict(checkpoint['model_state_dict'])
            print("Checkpoint loaded successfully")
        except (KeyError, RuntimeError) as e:
            print(f"Error loading checkpoint: {e}")
            print("Creating new model instead")
    else:
        print("No checkpoint found. Creating new model")
    
    return model

def custom_collate(batch):
    images, labels, patient_ids, series_uids = zip(*batch)
    
    # Pad images to the same size
    max_images = max(img.size(0) for img in images)
    padded_images = []
    for img in images:
        if img.size(0) < max_images:
            padding = torch.zeros(max_images - img.size(0), *img.size()[1:])
            img = torch.cat([img, padding], dim=0)
        padded_images.append(img)
    
    images = torch.stack(padded_images)
    labels = torch.stack(labels)
    
    return images, labels, patient_ids, series_uids

from torch.cuda.amp import autocast, GradScaler

def train_model_in_batches(model, studies_folders, dataset_path, batch_size=BATCH_SIZE, num_epochs=NUM_EPOCHS, accumulation_steps=4):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE)
    scaler = GradScaler()

    for epoch in range(num_epochs):
        print(f"Epoch {epoch+1}/{num_epochs}")
        for studies_folder in studies_folders:
            start_idx = 0
            while True:
                patient_data, clinical_data, next_start_idx = process_batch(studies_folder, dataset_path, start_idx, BATCH_SIZE, MAX_IMAGES_PER_SERIES)
                
                if not patient_data:
                    break  # No more data to process in this folder
                
                dataset = PatientDataset(patient_data, list(patient_data.keys()))
                dataloader = torch.utils.data.DataLoader(dataset, batch_size=CHUNK_SIZE, shuffle=True, collate_fn=custom_collate)
                
                for i, (images, labels, patient_ids, series_uids) in enumerate(dataloader):
                    print(f"Batch {i+1} - Images shape: {images.shape}, Labels shape: {labels.shape}")
                    images = images.to(device)
                    labels = labels.to(device)
                    
                    optimizer.zero_grad()
                    
                    for j in range(0, images.size(1), batch_size):
                        batch = images[:, j:j+batch_size].contiguous().view(-1, 3, IMG_SIZE[0], IMG_SIZE[1])
                        batch_labels = labels.repeat_interleave(batch_size, dim=0)
                        
                        print(f"  Sub-batch {j//batch_size + 1} - Batch shape: {batch.shape}, Batch labels shape: {batch_labels.shape}")

                        with autocast():
                            outputs = model(batch)
                            print(f"  Outputs shape: {outputs.shape}")
                            loss = criterion(outputs, batch_labels[:outputs.size(0)])
                        
                        scaler.scale(loss).backward()
                        
                        if (j + batch_size) % (batch_size * accumulation_steps) == 0:
                            scaler.step(optimizer)
                            scaler.update()
                            optimizer.zero_grad()

                    print(f"Batch {i+1} processed")
                
                start_idx = next_start_idx
                
                # Save checkpoint after each batch
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                }, CHECKPOINT_PATH)
                print(f"Checkpoint saved to {CHECKPOINT_PATH}")
                
    return model

class PatientDataset(Dataset):
    def __init__(self, patient_data, patient_ids):
        self.patient_data = patient_data
        self.patient_ids = patient_ids
        self.series_data = []
        
        for patient_id in self.patient_ids:
            patient = self.patient_data[patient_id]
            labels = patient['labels']
            label_tensor = torch.tensor([labels[key] for key in sorted(labels.keys())]).float()
            
            for series_uid, series_images in patient['images'].items():
                series_tensor = torch.tensor(series_images).float().permute(0, 3, 1, 2)
                self.series_data.append((series_tensor, label_tensor, patient_id, series_uid))
    
    def __len__(self):
        return len(self.series_data)
    
    def __getitem__(self, idx):
        return self.series_data[idx]

def save_final_model(model, path=CHECKPOINT_PATH):
    torch.save(model.state_dict(), path)
    print(f"Final model saved to {path}")

dataset_path = '/kaggle/input/mosmeddata-ct-hemorrhage-type-viii/MosMedData-CT-HEMORRHAGE-type VIII/'

# Get a list of all studies folders
# studies_folders = [f for f in os.listdir(dataset_path) if f.endswith('_studies')]
studies_folders = ['400_500_studies']
print(studies_folders)

#### Main execution
model = create_or_load_model(CHECKPOINT_PATH)

# Train the model in batches
model = train_model_in_batches(model, studies_folders, dataset_path)

# Save the final model
save_final_model(model)
# Out:
# ['400_500_studies']
# No checkpoint found. Creating new model
# Epoch 1/5
# Processing folder 400_500_studies
# /tmp/ipykernel_480/3492086485.py:193: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Processed 851 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.03050206031205090212101415130402, series UID: 1.2.643.5.1.13.13.12.2.77.8252.09030205031314101014040300050508
# Processed 551 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.12100603091102140112150804140706, series UID: 1.2.643.5.1.13.13.12.2.77.8252.05060713020912040111131210000303
# Processed 769 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.06010500031303140403080114141012, series UID: 1.2.643.5.1.13.13.12.2.77.8252.09061213110611041510050311120313
# Processed 251 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.14001507020807131402151406001108, series UID: 1.2.643.5.1.13.13.12.2.77.8252.00110701141401140814120108110706
# Processed 83 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.08010811121300080404100303090501, series UID: 1.2.643.5.1.13.13.12.2.77.8252.02140815040601101009000405050805
# Processed 329 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.08010811121300080404100303090501, series UID: 1.2.643.5.1.13.13.12.2.77.8252.00141014100713091010041413130801
# Processed 551 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.12111101051200140000131200051509, series UID: 1.2.643.5.1.13.13.12.2.77.8252.12081314040705130604061000140107
# Processed 426 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.14041006121111020803081112121501, series UID: 1.2.643.5.1.13.13.12.2.77.8252.03031102020200140407150900111515
# Processed 263 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.07001408080508050807090006001207, series UID: 1.2.643.5.1.13.13.12.2.77.8252.07110504150105110103030102080002
# Number of processed studies: 8
# Number of rows in clinical data: 9
# Batch 1 - Images shape: torch.Size([8, 851, 3, 224, 224]), Labels shape: torch.Size([8, 6])
#   Sub-batch 1 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
# /tmp/ipykernel_480/3492086485.py:221: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 2 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 3 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 4 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 5 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 6 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 7 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 8 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 9 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 10 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 11 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 12 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 13 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 14 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 15 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 16 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 17 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 18 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 19 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 20 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 21 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 22 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 23 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 24 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 25 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 26 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 27 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 28 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 29 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 30 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 31 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 32 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 33 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 34 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 35 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 36 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 37 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 38 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 39 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 40 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 41 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 42 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 43 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 44 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 45 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 46 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 47 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 48 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 49 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 50 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 51 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 52 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 53 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 54 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 55 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 56 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 57 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 58 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 59 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 60 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 61 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 62 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 63 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 64 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 65 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 66 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 67 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 68 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 69 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 70 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 71 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 72 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 73 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 74 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 75 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 76 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 77 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 78 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 79 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 80 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 81 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 82 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 83 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 84 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 85 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 86 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 87 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 88 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 89 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 90 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 91 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 92 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 93 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 94 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 95 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 96 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 97 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 98 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 99 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 100 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 101 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 102 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 103 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 104 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 105 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 106 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 107 - Batch shape: torch.Size([24, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([24, 6])
# Batch 1 processed
# Batch 2 - Images shape: torch.Size([1, 551, 3, 224, 224]), Labels shape: torch.Size([1, 6])
#   Sub-batch 1 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 2 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 3 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 4 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 5 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 6 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 7 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 8 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 9 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 10 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 11 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 12 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 13 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 14 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 15 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 16 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 17 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 18 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 19 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 20 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 21 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 22 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 23 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 24 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 25 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 26 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 27 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 28 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 29 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 30 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 31 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 32 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 33 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 34 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 35 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 36 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 37 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 38 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 39 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 40 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 41 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 42 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 43 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 44 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 45 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 46 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 47 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 48 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 49 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 50 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 51 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 52 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 53 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 54 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 55 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 56 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 57 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 58 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 59 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 60 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 61 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 62 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 63 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 64 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 65 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 66 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 67 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 68 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 69 - Batch shape: torch.Size([7, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([7, 6])
# Batch 2 processed
# Checkpoint saved to /kaggle/working/model_checkpoint.pth
# Processing folder 400_500_studies
# Processed 851 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.12000612021506121208140010020412, series UID: 1.2.643.5.1.13.13.12.2.77.8252.00120908040501051113150104070502
# Processed 709 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.04030409050605001409120711000506, series UID: 1.2.643.5.1.13.13.12.2.77.8252.05060506130400130510150209011513
# Processed 877 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.11001001061207090103150909020010, series UID: 1.2.643.5.1.13.13.12.2.77.8252.12140009121311041108091304011503
# Processed 721 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.11001001061207090103150909020010, series UID: 1.2.643.5.1.13.13.12.2.77.8252.10001313051010000013120510101006
# Processed 251 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.00060407110511120709131406060707, series UID: 1.2.643.5.1.13.13.12.2.77.8252.13020901030300110801140712150003
# Processed 238 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.10130802141211010705111512130804, series UID: 1.2.643.5.1.13.13.12.2.77.8252.14040507141103131402130307141008
# Processed 251 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.11110613071307110801110408070004, series UID: 1.2.643.5.1.13.13.12.2.77.8252.11120514120808020600090206020713
# Processed 124 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.11110613071307110801110408070004, series UID: 1.2.643.5.1.13.13.12.2.77.8252.00101107041205150913030214101002
# Processed 721 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.15061405140112091001091213150102, series UID: 1.2.643.5.1.13.13.12.2.77.8252.03070006141401050810111102030104
# Processed 263 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.04050306001014050413141007061501, series UID: 1.2.643.5.1.13.13.12.2.77.8252.09141002101510150004140202010110
# Number of processed studies: 8
# Number of rows in clinical data: 10
# Batch 1 - Images shape: torch.Size([8, 877, 3, 224, 224]), Labels shape: torch.Size([8, 6])
#   Sub-batch 1 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 2 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
# /tmp/ipykernel_480/3492086485.py:221: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
#   Sub-batch 3 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 4 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 5 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 6 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 7 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 8 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 9 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 10 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 11 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 12 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 13 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 14 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 15 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 16 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 17 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 18 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 19 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 20 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 21 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 22 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 23 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 24 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 25 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 26 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 27 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 28 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 29 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 30 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 31 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 32 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 33 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 34 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 35 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 36 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 37 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 38 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 39 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 40 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 41 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 42 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 43 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 44 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 45 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 46 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 47 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 48 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 49 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 50 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 51 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 52 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 53 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 54 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 55 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 56 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 57 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 58 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 59 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 60 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 61 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 62 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 63 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 64 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 65 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 66 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 67 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 68 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 69 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 70 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 71 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 72 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 73 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 74 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 75 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 76 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 77 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 78 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 79 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 80 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 81 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 82 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 83 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 84 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 85 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 86 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 87 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 88 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 89 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 90 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 91 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 92 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 93 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 94 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 95 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 96 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 97 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 98 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 99 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 100 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 101 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 102 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 103 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 104 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 105 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 106 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 107 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 108 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 109 - Batch shape: torch.Size([64, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([64, 6])
#   Sub-batch 110 - Batch shape: torch.Size([40, 3, 224, 224]), Batch labels shape: torch.Size([64, 6])
#   Outputs shape: torch.Size([40, 6])
# Batch 1 processed
# Batch 2 - Images shape: torch.Size([2, 851, 3, 224, 224]), Labels shape: torch.Size([2, 6])
#   Sub-batch 1 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 2 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 3 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 4 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 5 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 6 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 7 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 8 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 9 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 10 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 11 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 12 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 13 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 14 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 15 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 16 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 17 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 18 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 19 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 20 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 21 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 22 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 23 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 24 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 25 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 26 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 27 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 28 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
#   Outputs shape: torch.Size([16, 6])
#   Sub-batch 29 - Batch shape: torch.Size([16, 3, 224, 224]), Batch labels shape: torch.Size([16, 6])
# ...
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 9 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 10 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 11 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 12 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 13 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 14 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 15 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 16 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 17 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 18 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 19 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 20 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 21 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 22 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 23 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 24 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 25 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 26 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 27 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 28 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 29 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 30 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 31 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 32 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 33 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 34 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 35 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 36 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 37 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 38 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 39 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 40 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 41 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 42 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 43 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 44 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 45 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 46 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 47 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 48 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 49 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 50 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 51 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 52 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 53 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 54 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 55 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 56 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 57 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 58 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 59 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 60 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 61 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 62 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 63 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 64 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 65 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 66 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 67 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 68 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 69 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 70 - Batch shape: torch.Size([8, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([8, 6])
#   Sub-batch 71 - Batch shape: torch.Size([7, 3, 224, 224]), Batch labels shape: torch.Size([8, 6])
#   Outputs shape: torch.Size([7, 6])
# Batch 2 processed
# Checkpoint saved to /kaggle/working/model_checkpoint.pth
# Processing folder 400_500_studies
# Processed 684 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.13140305060812041409080300091409, series UID: 1.2.643.5.1.13.13.12.2.77.8252.09080813010606150008061200091012
# Processed 551 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.01120309040311051401110509150809, series UID: 1.2.643.5.1.13.13.12.2.77.8252.11070509090708000802151002120712
# Warning: No clinical data found for study UID: 1.2.643.5.1.13.13.12.2.77.8252.15040804110009001508121115040702
# Processed 319 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.13140412080101090900081202110101, series UID: 1.2.643.5.1.13.13.12.2.77.8252.15040004040403071014101314051209
# Processed 426 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.05070601031102000104000107151510, series UID: 1.2.643.5.1.13.13.12.2.77.8252.04131312100903060907131413090213
# Processed 661 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.13090312061515041004030612080613, series UID: 1.2.643.5.1.13.13.12.2.77.8252.07150515010508100113150000100112
# Processed 701 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.13110311140307000715090310000515, series UID: 1.2.643.5.1.13.13.12.2.77.8252.10100912020008051512110703141315
# Processed 709 DICOM images for study UID: 1.2.643.5.1.13.13.12.2.77.8252.10150212140809071210041101050906, series UID: 1.2.643.5.1.13.13.12.2.77.8252.05050310020411031215080405151011
# Number of processed studies: 8
# Number of rows in clinical data: 7
# Warning: No clinical data for study UID: 1.2.643.5.1.13.13.12.2.77.8252.15040804110009001508121115040702
# Batch 1 - Images shape: torch.Size([7, 709, 3, 224, 224]), Labels shape: torch.Size([7, 6])
#   Sub-batch 1 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 2 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
# /tmp/ipykernel_480/3492086485.py:221: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
#   Sub-batch 3 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 4 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 5 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 6 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 7 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 8 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 9 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 10 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 11 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 12 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 13 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 14 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 15 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 16 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 17 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 18 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 19 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 20 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 21 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 22 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 23 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 24 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 25 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 26 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 27 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 28 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 29 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 30 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 31 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 32 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 33 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 34 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 35 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 36 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 37 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 38 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 39 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
#   Outputs shape: torch.Size([56, 6])
#   Sub-batch 40 - Batch shape: torch.Size([56, 3, 224, 224]), Batch labels shape: torch.Size([56, 6])
